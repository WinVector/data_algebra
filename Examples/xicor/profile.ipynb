# %%
# to profile
# https://docs.python.org/3/library/profile.html
# import cProfile
# cProfile.run('our_xicor = [xicor(a, b) for i in range(len(ref_xicor))]', 'restats')

import pstats
from pstats import SortKey
p = pstats.Stats('restats')
p.strip_dirs().sort_stats(SortKey.CUMULATIVE).print_stats(200)
# Out:
# Mon Dec 27 21:05:40 2021    restats
#
#          5443105 function calls (5329805 primitive calls) in 4.003 seconds
#
#    Ordered by: cumulative time
#    List reduced from 939 to 200 due to restriction <200>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    4.003    4.003 {built-in method builtins.exec}
#         1    0.000    0.000    4.003    4.003 <string>:1(<module>)
#         1    0.001    0.001    4.003    4.003 <string>:1(<listcomp>)
#       100    0.001    0.000    4.002    0.040 <ipython-input-4-1493d1751819>:84(xicor)
#       100    0.001    0.000    3.954    0.040 data_ops.py:421(transform)
#       100    0.000    0.000    3.927    0.039 data_ops.py:387(eval)
#       100    0.001    0.000    3.927    0.039 data_ops.py:1818(eval_implementation_)
#       100    0.000    0.000    3.926    0.039 pandas_base.py:652(select_columns_step)
# ...
